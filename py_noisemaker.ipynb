# %% [markdown]
# <a href="https://colab.research.google.com/github/noisefactorllc/noisemaker/blob/main/py_noisemaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Noisemaker:

# %%
# !git clone https://github.com/noisefactorllc/noisemaker.git
# !pip install -r noisemaker/requirements.txt
# !cd noisemaker && pip install .

# %% [markdown]
# Generate an image from a random preset:

# %%
# !noisemaker generator random --height 1024 --width 1024

from IPython.display import Image
Image('art.png')

# %% [markdown]
# Apply a random effect preset to the image:

# %%
# !noisemaker effect random --no-resize art.png

from IPython.display import Image
Image('mangled.png')
